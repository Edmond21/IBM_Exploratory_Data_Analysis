# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/jacob/OneDrive/Desktop/IBM HR Analytics/archive/HR_Employee_Attrition.csv')

# %%
df_filtered1 = df[ df['Attrition'] == 'Yes' ]

# %%
df_filtered = df_filtered1.drop(["Attrition", "DailyRate", "EmployeeCount", "EmployeeNumber", "MonthlyIncome", "MonthlyRate", "Over18"], axis = 1)

# %%
df_no1 = df[df['Attrition'] == 'No']
df_no = df_no1.drop(["Attrition", "DailyRate", "EmployeeCount", "EmployeeNumber", "MonthlyIncome", "MonthlyRate", "Over18"], axis = 1)

# %%
for col in df_filtered.columns:
    print(col)
# Out:
# Age
# BusinessTravel
# Department
# DistanceFromHome
# Education
# EducationField
# EnvironmentSatisfaction
# Gender
# HourlyRate
# JobInvolvement
# JobLevel
# JobRole
# JobSatisfaction
# MaritalStatus
# NumCompaniesWorked
# OverTime
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StandardHours
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
df_filtered.rename(columns = {'BusinessTravel':'Travel', 'Department':'Dept', 'DistanceFromHome':'DistHome', 'Education':'EduLvl', 'EducationField':'EduField', 'EnvironmentSatisfaction':'EnviroSat', 'JobInvolvement':'JobInvolv', 'JobSatisfaction':'JobSat', 'NumCompaniesWorked':'#CoWorked', 'PercentSalaryHike':'%SalHike', 'PerformanceRating':'Performance', 'RelationshipSatisfaction':'RelationSat', 'StandardHours':'StdHrs', 'StockOptionLevel':'StockOpLvl', 'TotalWorkingYears':'#YrsWorked', 'TrainingTimesLastYear':'HrsTrainedLstYr', 'YearsAtCompany':'YrsCo', 'YearsInCurrentRole':'YrsCurrRole', 'YearsSinceLastPromotion':'YrsSinceLstPromo', 'YearsWithCurrManager':'YrsWCurrManag'}, inplace = True)
for col in df_filtered.columns:
    print(col)
# Out:
# Age
# Travel
# Dept
# DistHome
# EduLvl
# EduField
# EnviroSat
# Gender
# HourlyRate
# JobInvolv
# JobLevel
# JobRole
# JobSat
# MaritalStatus
# #CoWorked
# OverTime
# %SalHike
# Performance
# RelationSat
# StdHrs
# StockOpLvl
# #YrsWorked
# HrsTrainedLstYr
# WorkLifeBalance
# YrsCo
# YrsCurrRole
# YrsSinceLstPromo
# YrsWCurrManag

# %%
df.rename(columns = {'BusinessTravel':'Travel', 'Department':'Dept', 'DistanceFromHome':'DistHome', 'Education':'EduLvl', 'EducationField':'EduField', 'EnvironmentSatisfaction':'EnviroSat', 'JobInvolvement':'JobInvolv', 'JobSatisfaction':'JobSat', 'NumCompaniesWorked':'#CoWorked', 'PercentSalaryHike':'%SalHike', 'PerformanceRating':'Performance', 'RelationshipSatisfaction':'RelationSat', 'StandardHours':'StdHrs', 'StockOptionLevel':'StockOpLvl', 'TotalWorkingYears':'#YrsWorked', 'TrainingTimesLastYear':'HrsTrainedLstYr', 'YearsAtCompany':'YrsCo', 'YearsInCurrentRole':'YrsCurrRole', 'YearsSinceLastPromotion':'YrsSinceLstPromo', 'YearsWithCurrManager':'YrsWCurrManag'}, inplace = True)

# %%
df_no.rename(columns = {'BusinessTravel':'Travel', 'Department':'Dept', 'DistanceFromHome':'DistHome', 'Education':'EduLvl', 'EducationField':'EduField', 'EnvironmentSatisfaction':'EnviroSat', 'JobInvolvement':'JobInvolv', 'JobSatisfaction':'JobSat', 'NumCompaniesWorked':'#CoWorked', 'PercentSalaryHike':'%SalHike', 'PerformanceRating':'Performance', 'RelationshipSatisfaction':'RelationSat', 'StandardHours':'StdHrs', 'StockOptionLevel':'StockOpLvl', 'TotalWorkingYears':'#YrsWorked', 'TrainingTimesLastYear':'HrsTrainedLstYr', 'YearsAtCompany':'YrsCo', 'YearsInCurrentRole':'YrsCurrRole', 'YearsSinceLastPromotion':'YrsSinceLstPromo', 'YearsWithCurrManager':'YrsWCurrManag'}, inplace = True)

# %%
Age_Dist = sns.distplot(df_filtered['Age']).set_title("Frequency Distribution of Age")
Age_Dist
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Frequency Distribution of Age')

# %%
Dept = df_filtered['Dept'].value_counts()[:20].plot(kind='barh').set_title("Department")
Dept
# Out:
# Text(0.5, 1.0, 'Department')

# %%
Dist = sns.distplot(df_filtered['DistHome'])
Dist
All = sns.distplot(df_no['DistHome']).set_title("All Employee Distance From Home")
All
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
EduLvl_Yes = sns.distplot(df_filtered['EduLvl'])
EduLvl_Yes
EduLvl_No = sns.distplot(df_no['EduLvl']).set_title("All Employee Education Level")
EduLvl_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
EduLvl_Yes = df_filtered['EduField'].value_counts()[:20].plot(kind='barh').set_title("Education Field of Former Employees")
EduLvl_Yes
# Out:
# Text(0.5, 1.0, 'Education Field of Former Employees')

# %%
EduLvl_No = df_no['EduField'].value_counts()[:20].plot(kind='barh').set_title("Education Field of Current Employees")
EduLvl_No
# Out:
# Text(0.5, 1.0, 'Education Field of Current Employees')

# %%
EnviroSat_Yes = sns.distplot(df_filtered['EnviroSat'])
EnviroSat_Yes
EnviroSat_No = sns.distplot(df_no['EnviroSat']).set_title("All Employee Environmental Satisfaction")
EnviroSat_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Gender_Yes = df_filtered['Gender'].value_counts()[:20].plot(kind='barh').set_title("Gender of Former Employees")
Gender_Yes
# Out:
# Text(0.5, 1.0, 'Gender of Former Employees')

# %%
HrlyRate_Yes = sns.distplot(df_filtered['HourlyRate'])
HrlyRate_Yes
HrlyRate_No = sns.distplot(df_no['HourlyRate']).set_title("All Employee Hourly Rate")
HrlyRate_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
JobInvolv_Yes = sns.distplot(df_filtered['JobInvolv'])
JobInvolv_Yes
JobInvolv_No = sns.distplot(df_no['JobInvolv']).set_title("All Employee Job Involvement")
JobInvolv_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
JobLvl_Yes = sns.distplot(df_filtered['JobLevel'])
JobLvl_Yes
JobLvl_No = sns.distplot(df_no['JobLevel']).set_title("All Employees Job Levels")
JobLvl_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
JobRole_Yes = df_filtered['JobRole'].value_counts()[:20].plot(kind='barh').set_title("Job Role of Former Employees")
JobRole_Yes
# Out:
# Text(0.5, 1.0, 'Job Role of Former Employees')

# %%
JobRole_No = df_no['JobRole'].value_counts()[:20].plot(kind='barh').set_title("Job Role of Current Employees")
JobRole_No
# Out:
# Text(0.5, 1.0, 'Job Role of Current Employees')

# %%
JobSat_Yes = sns.distplot(df_filtered['JobSat'])
JobSat_Yes
JobSat_No = sns.distplot(df_no['JobSat']).set_title("All Employees Job Satisfaction")
JobSat_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
MaritalStatus_Yes = df_filtered['MaritalStatus'].value_counts()[:20].plot(kind='barh').set_title("Marital Status of Former Employees")
MaritalStatus_Yes
# Out:
# Text(0.5, 1.0, 'Marital Status of Former Employees')

# %%
MaritalStatus_No = df_no['MaritalStatus'].value_counts()[:20].plot(kind='barh').set_title("Marital Status of Current Employees")
MaritalStatus_No
# Out:
# Text(0.5, 1.0, 'Marital Status of Current Employees')

# %%
NumCo_Yes = sns.distplot(df_filtered['#CoWorked'])
NumCo_Yes
NumCo_No = sns.distplot(df_no['#CoWorked']).set_title("All Employee Number of Companies Worked")
NumCo_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
OT_Yes = df_filtered['OverTime'].value_counts()[:20].plot(kind='barh').set_title("Former Employee Over Time")
OT_Yes
# Out:
# Text(0.5, 1.0, 'Former Employee Over Time')

# %%
OT_No = df_no['OverTime'].value_counts()[:20].plot(kind='barh').set_title("Current Employee Over Time")
OT_No
# Out:
# Text(0.5, 1.0, 'Current Employee Over Time')

# %%
SalHike_Yes = sns.distplot(df_filtered['%SalHike'])
SalHike_Yes
SalHike_No = sns.distplot(df_no['%SalHike']).set_title("All Employee Percent Salary Hike")
SalHike_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Perform_Yes = df_filtered['Performance'].value_counts()[:20].plot(kind='barh').set_title("Former Employee Performance Rating")
Perform_Yes
# Out:
# Text(0.5, 1.0, 'Former Employee Performance Rating')

# %%
Perform_No = df_no['Performance'].value_counts()[:20].plot(kind='barh').set_title("Current Employee Performance Rating")
Perform_No
# Out:
# Text(0.5, 1.0, 'Current Employee Performance Rating')

# %%
RelationSat_Yes = sns.distplot(df_filtered['RelationSat'])
RelationSat_Yes
RelationSat_No = sns.distplot(df_no['RelationSat']).set_title("All Employee Manager Relatioship Satisfaction")
RelationSat_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
StockOp_Yes = sns.distplot(df_filtered['StockOpLvl'])
StockOp_Yes
StockOp_No = sns.distplot(df_no['StockOpLvl']).set_title("All Employee Stock Option Level")
StockOp_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsWorked_Yes = sns.distplot(df_filtered['#YrsWorked'])
YrsWorked_Yes
YrsWorked_No = sns.distplot(df_no['#YrsWorked']).set_title("All Employee Total Working Years")
YrsWorked_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
TrainTime_Yes = sns.distplot(df_filtered['HrsTrainedLstYr'])
TrainTime_Yes
TrainTime_No = sns.distplot(df_no['HrsTrainedLstYr']).set_title("All Employee Hours Trained Last Year")
TrainTime_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
WrkLife_Yes = sns.distplot(df_filtered['WorkLifeBalance'])
WrkLife_Yes
WrkLife_No = sns.distplot(df_no['WorkLifeBalance']).set_title("All Employee Work Life Balance Rating")
WrkLife_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsCo_Yes = sns.distplot(df_filtered['YrsCo'])
YrsCo_Yes
YrsCo_No = sns.distplot(df_no['YrsCo']).set_title("All Employee Years Worked at Company")
YrsCo_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsCurrRole_Yes = sns.distplot(df_filtered['YrsCurrRole'])
YrsCurrRole_Yes
YrsCurrRole_No = sns.distplot(df_no['YrsCurrRole']).set_title("All Employee Years in Current Role")
YrsCurrRole_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsPromo_Yes = sns.distplot(df_filtered['YrsSinceLstPromo'])
YrsPromo_Yes
YrsPromo_No = sns.distplot(df_no['YrsSinceLstPromo']).set_title("All Employee Years Since Last Promotion")
YrsPromo_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsCurrManag_Yes = sns.distplot(df_filtered['YrsWCurrManag'])
YrsCurrManag_Yes
YrsCurrManag_No = sns.distplot(df_no['YrsWCurrManag']).set_title("All Employee Years With Current Maanger")
YrsCurrManag_No
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_Sales = df_filtered[ df_filtered['Dept'] == 'Sales' ]
df_Sales.rename(columns = {'BusinessTravel':'Travel', 'Department':'Dept', 'DistanceFromHome':'DistHome', 'Education':'EduLvl', 'EducationField':'EduField', 'EnvironmentSatisfaction':'EnviroSat', 'JobInvolvement':'JobInvolv', 'JobSatisfaction':'JobSat', 'NumCompaniesWorked':'#CoWorked', 'PercentSalaryHike':'%SalHike', 'PerformanceRating':'Performance', 'RelationshipSatisfaction':'RelationSat', 'StandardHours':'StdHrs', 'StockOptionLevel':'StockOpLvl', 'TotalWorkingYears':'#YrsWorked', 'TrainingTimesLastYear':'HrsTrainedLstYr', 'YearsAtCompany':'YrsCo', 'YearsInCurrentRole':'YrsCurrRole', 'YearsSinceLastPromotion':'YrsSinceLstPromo', 'YearsWithCurrManager':'YrsWCurrManag'}, inplace = True)
df_RD = df_filtered[df_filtered['Dept'] == 'Research & Development']
df_RD.rename(columns = {'BusinessTravel':'Travel', 'Department':'Dept', 'DistanceFromHome':'DistHome', 'Education':'EduLvl', 'EducationField':'EduField', 'EnvironmentSatisfaction':'EnviroSat', 'JobInvolvement':'JobInvolv', 'JobSatisfaction':'JobSat', 'NumCompaniesWorked':'#CoWorked', 'PercentSalaryHike':'%SalHike', 'PerformanceRating':'Performance', 'RelationshipSatisfaction':'RelationSat', 'StandardHours':'StdHrs', 'StockOptionLevel':'StockOpLvl', 'TotalWorkingYears':'#YrsWorked', 'TrainingTimesLastYear':'HrsTrainedLstYr', 'YearsAtCompany':'YrsCo', 'YearsInCurrentRole':'YrsCurrRole', 'YearsSinceLastPromotion':'YrsSinceLstPromo', 'YearsWithCurrManager':'YrsWCurrManag'}, inplace = True)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
EduLvl_Sales = sns.distplot(df_Sales['EduLvl'])
EduLvl_Sales
EduLvl_RD = sns.distplot(df_RD['EduLvl']).set_title("Sales and R&D Employees Education Level")
EduLvl_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
EduLvl_Sales = df_Sales['EduField'].value_counts()[:20].plot(kind='barh').set_title("Education Field of Former Employees")
EduLvl_Sales
# Out:
# Text(0.5, 1.0, 'Education Field of Former Employees')

# %%
EduLvl_RD = df_RD['EduField'].value_counts()[:20].plot(kind='barh').set_title("Education Field of Former Employees")
EduLvl_RD
# Out:
# Text(0.5, 1.0, 'Education Field of Former Employees')

# %%
EnviroSat_Sales = sns.distplot(df_Sales['EnviroSat'])
EnviroSat_Sales
EnviroSat_RD = sns.distplot(df_RD['EnviroSat']).set_title("Environmental Satisfaction of Former Sales and R&D Employees")
EnviroSat_RD
plt.legend(labels=['Sales','RD'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Gender_Sales = df_Sales['Gender'].value_counts()[:20].plot(kind='barh').set_title("Gender of Former Sales Employees")
Gender_Sales
# Out:
# Text(0.5, 1.0, 'Gender of Former Sales Employees')

# %%
Gender_RD = df_RD['Gender'].value_counts()[:20].plot(kind='barh').set_title("Gender of Former R&D Employees")
Gender_RD
# Out:
# Text(0.5, 1.0, 'Gender of Former R&D Employees')

# %%
HrlyRate_Sales = sns.distplot(df_Sales['HourlyRate'])
HrlyRate_Sales
HrlyRate_RD = sns.distplot(df_RD['HourlyRate']).set_title("Sales and R&D Employees Hourly Rate")
HrlyRate_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
JobInvolv_Sales = sns.distplot(df_Sales['JobInvolv'])
JobInvolv_Sales
JobInvolv_RD = sns.distplot(df_RD['JobInvolv']).set_title("Sales and R&D Employees Job Involvement")
JobInvolv_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
JobLvl_Sales = sns.distplot(df_Sales['JobLevel'])
JobLvl_Sales
JobLvl_RD = sns.distplot(df_RD['JobLevel']).set_title("Sales and R&D Employees Job Levels")
JobLvl_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
JobRole_Sales = df_Sales['JobRole'].value_counts()[:20].plot(kind='barh').set_title("Job Role of Former Sales Employees")
JobRole_Sales
# Out:
# Text(0.5, 1.0, 'Job Role of Former Sales Employees')

# %%
JobRole_RD = df_RD['JobRole'].value_counts()[:20].plot(kind='barh').set_title("Job Role of Former R&D Employees")
JobRole_RD
# Out:
# Text(0.5, 1.0, 'Job Role of Former R&D Employees')

# %%
JobSat_Sales = sns.distplot(df_Sales['JobSat'])
JobSat_Sales
JobSat_RD = sns.distplot(df_RD['JobSat']).set_title("Sales and R&D Employees Job Satisfaction")
JobSat_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
MaritalStatus_Sales = df_Sales['MaritalStatus'].value_counts()[:20].plot(kind='barh').set_title("Marital Status of Former Sales Employees")
MaritalStatus_Sales
# Out:
# Text(0.5, 1.0, 'Marital Status of Former Sales Employees')

# %%
MaritalStatus_RD = df_RD['MaritalStatus'].value_counts()[:20].plot(kind='barh').set_title("Marital Status of Former R&D Employees")
MaritalStatus_RD
# Out:
# Text(0.5, 1.0, 'Marital Status of Former R&D Employees')

# %%
NumCo_Sales = sns.distplot(df_Sales['#CoWorked'])
NumCo_Sales
NumCo_RD = sns.distplot(df_RD['#CoWorked']).set_title("Sales and R&D Employees Number of Companies Worked")
NumCo_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
OT_Sales = df_Sales['OverTime'].value_counts()[:20].plot(kind='barh').set_title("Former Sales Employee Over Time")
OT_Sales
# Out:
# Text(0.5, 1.0, 'Former Sales Employee Over Time')

# %%
OT_RD = df_RD['OverTime'].value_counts()[:20].plot(kind='barh').set_title("Former R&D Employee Over Time")
OT_RD
# Out:
# Text(0.5, 1.0, 'Former R&D Employee Over Time')

# %%
SalHike_Sales = sns.distplot(df_filtered['%SalHike'])
SalHike_Sales
SalHike_RD = sns.distplot(df_no['%SalHike']).set_title("Sales and R&D Employee Percent Salary Hike")
SalHike_RD
plt.legend(labels=['Former','Current'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
Perform_Sales = df_Sales['Performance'].value_counts()[:20].plot(kind='barh').set_title("Former Sales Employee Performance Rating")
Perform_Sales
# Out:
# Text(0.5, 1.0, 'Former Sales Employee Performance Rating')

# %%
Perform_RD = df_RD['Performance'].value_counts()[:20].plot(kind='barh').set_title("Former R&D Employee Performance Rating")
Perform_RD
# Out:
# Text(0.5, 1.0, 'Former R&D Employee Performance Rating')

# %%
RelationSat_Sales = sns.distplot(df_filtered['RelationSat'])
RelationSat_Sales
RelationSat_RD = sns.distplot(df_no['RelationSat']).set_title("Sales and R&D Employee Manager Relatioship Satisfaction")
RelationSat_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
StockOp_Sales = sns.distplot(df_filtered['StockOpLvl'])
StockOp_Sales
StockOp_RD = sns.distplot(df_no['StockOpLvl']).set_title("Sales and R&D Employee Stock Option Level")
StockOp_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsWorked_Sales = sns.distplot(df_Sales['#YrsWorked'])
YrsWorked_Sales
YrsWorked_RD = sns.distplot(df_RD['#YrsWorked']).set_title("Sales and R&D Employee Total Working Years")
YrsWorked_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
TrainTime_Sales = sns.distplot(df_Sales['HrsTrainedLstYr'])
TrainTime_Sales
TrainTime_No = sns.distplot(df_RD['HrsTrainedLstYr']).set_title("Sales and R&D Employee Hours Trained Last Year")
TrainTime_No
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
WrkLife_Sales = sns.distplot(df_Sales['WorkLifeBalance'])
WrkLife_Sales
WrkLife_RD = sns.distplot(df_RD['WorkLifeBalance']).set_title("Sales and R&D Employee Work Life Balance Rating")
WrkLife_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsCo_Sales = sns.distplot(df_Sales['YrsCo'])
YrsCo_Sales
YrsCo_RD = sns.distplot(df_RD['YrsCo']).set_title("Sales and R&D Employee Years Worked at Company")
YrsCo_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsCurrRole_Sales = sns.distplot(df_Sales['YrsCurrRole'])
YrsCurrRole_Sales
YrsCurrRole_RD = sns.distplot(df_RD['YrsCurrRole']).set_title("Sales and R&D Employee Years in Current Role")
YrsCurrRole_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsPromo_Sales = sns.distplot(df_Sales['YrsSinceLstPromo'])
YrsPromo_Sales
YrsPromo_RD = sns.distplot(df_RD['YrsSinceLstPromo']).set_title("Sales and R&D Employee Years Since Last Promotion")
YrsPromo_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
YrsCurrManag_Sales = sns.distplot(df_Sales['YrsWCurrManag'])
YrsCurrManag_Sales
YrsCurrManag_RD = sns.distplot(df_RD['YrsWCurrManag']).set_title("Sales and R&D Employee Years With Current Maanger")
YrsCurrManag_RD
plt.legend(labels=['Sales','R&D'],fontsize = 12)
# Out:
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\jacob\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
